# %%
import pandas as pd
from glob import glob
import os
import numpy as np
import re
import sys
from collections import defaultdict
import itertools
sys.path.append('utils/')
from airforce_python_scraper import states
from fuzzywuzzy import fuzz

# %%
ls ../data/sapro/SAPRO\ Annual\ Reports
# Out:
# SAPRO_13_all.xlsx          SAPRO_2015/
# SAPRO_14_all.xlsx          SAPRO_2016/
# SAPRO_15_all.xlsx          SAPRO_all.xlsx
# SAPRO_16_all.xlsx          SAPRO_charts_army_14.xlsx
# SAPRO_2013/                misc/
# SAPRO_2014/

# %%
ls ../data/sapro/SAPRO\ Annual\ Reports/SAPRO_2015
# Out:
# FY15_Annual_Report_on_Sexual_Assault_in_the_Military_Full_Report.pdf
# SAPRO_charts_airforce_15.pdf
# SAPRO_charts_army_15.pdf
# SAPRO_charts_marinecorps_15.pdf
# SAPRO_charts_navy_15.pdf
# workbooks/

# %%
ls ../data/sapro/SAPRO\ Annual\ Reports/
# Out:
# SAPRO_13_all.xlsx          SAPRO_2015/
# SAPRO_14_all.xlsx          SAPRO_2016/
# SAPRO_15_all.xlsx          SAPRO_all.xlsx
# SAPRO_16_all.xlsx          SAPRO_charts_army_14.xlsx
# SAPRO_2013/                misc/
# SAPRO_2014/

# %% [markdown]
# # Get and clean SAPRO data

# %%
sapro_tables = [(pd.read_excel(path)
         .assign(Year='20' + re.search('\d\d', path).group())
) for path in glob('../data/sapro/SAPRO Annual Reports/SAPRO_*_all.xlsx')
                + ['../data/sapro/SAPRO Annual Reports/SAPRO_charts_army_14.xlsx']
]

# %%
def clean_colname(col):
    return (col.replace('\r', ' ')
                  .replace('Administra- tive Discharge Type', 'Administrative Discharge Type')
                  .replace('Confinemen t', 'Confinement')
                  .replace('Incident Location', 'Location')
                  .replace('Quarter Dispositio n Complete d', 'Quarter Disposition Completed')
                  .replace('applicable.', 'applicable')
                  .replace('Acession ?', 'Acession?')
                  .replace('Restrictio n', 'Restriction')
                  .replace('Investi- gation', 'Investigation')
                  .replace('Victim Grade', 'Victim Pay Grade')
                  .replace('Subject Grade', 'Subject Pay Grade')
                  .replace('Subject Affiliation', 'Subject Service')
                  )

# %%
cleaned_tables = [table.rename(
    columns={col:clean_colname(col) for col in table.columns}
) for table in sapro_tables]

# %%
sapro_full = pd.concat(cleaned_tables).reset_index(drop=True)
sapro_full = sapro_full.applymap(lambda x: x.replace('\r', ' ') if isinstance(x, basestring) else x)

# %%
## further exploration

# %%
corrs = []
for idx1 in range(len(sapro_full.columns)):
    for idx2 in range(idx1+1, len(sapro_full.columns)):
        corrs.append({
            'col1': sapro_full.columns[idx1], 'co12': sapro_full.columns[idx2],
            'corr':sapro_full.iloc[:, [idx1, idx2]].isnull().corr().iloc[0, 1]
        })

# %%
pd.DataFrame(corrs).pipe(lambda df: df[df['corr'] < -.8])
# Out:
#                               co12  \
# 546         Narrative of the Crime
# 548  Offense Alleged/ Investigated
# 625             Victim Affiliation
# 662             Victim Affiliation
#
#                                                   col1      corr
# 546  Most Serious Sexual Assault Allegation Subject... -0.952349
# 548  Most Serious Sexual Assault Allegation Subject... -0.954824
# 625                             Narrative of the Crime -0.825029
# 662                      Offense Alleged/ Investigated -0.827173

# %%
sapro_full['Subject Pay Grade'].isnull().value_counts()
# Out:
# False    7199
# True     1164
# Name: Subject Pay Grade, dtype: int64

# %%
sapro_full['Year'].value_counts()
# Out:
# 2014    2254
# 2015    2080
# 2013    2041
# 2016    1988
# Name: Year, dtype: int64

# %%
###### How many Subject Pay Grades are null?

# %%
(sapro_full
 .groupby(['Year', 'Subject Service'])
 .apply(lambda x: x['Subject Pay Grade'].isnull().value_counts())
 .reset_index()
 .pipe(lambda df: df[df['level_2'] == True])
 .pipe(lambda df: df[df['Subject Service'] != 'Unknown'])
)
# Out:
#     Year Subject Service  level_2  Subject Pay Grade
# 1   2013       Air Force     True                273
# 8   2014       Air Force     True                  8
# 10  2014            Army     True                  1
# 17  2015       Air Force     True                  5
# 21  2015            Navy     True                  1
# 25  2016       Air Force     True                  7
# 27  2016             DoD     True                  1

# %%
##### How many locations are null?

# %%
(sapro_full
 .groupby(['Year','Subject Service'])['Location']
 .apply(lambda x: x.isnull().value_counts())
 .reset_index()
 .pipe(lambda df: df[df['level_2'] == True])
)
# Out:
#     Year Subject Service  level_2  Location
# 6   2014       Air Force     True       153
# 8   2014            Army     True       512
# 11  2014             DoD     True         1
# 13  2014    Marine Corps     True        91
# 15  2014            Navy     True       135
# 17  2014         Unknown     True       126
# 19  2015       Air Force     True       157
# 20  2015            Army     True       658
# 23  2015    Marine Corps     True        43
# 25  2015            Navy     True        68
# 27  2015         Unknown     True       148
# 29  2016       Air Force     True        55
# 31  2016            Army     True       248
# 32  2016             DoD     True         1
# 34  2016    Marine Corps     True        18
# 36  2016            Navy     True        22
# 39  2016         Unknown     True       110

# %% [markdown]
# # Get and clean Court Martial data

# %%
summary_tables = [
    pd.read_csv(path,index_col=0).assign(division=os.path.basename(path).split('_')[0])
    for path in glob('../data/final_data/court_martial_summaries/*')
]
summary_tables = map(lambda table: table.rename(columns={
    col: col.replace('date', 'Date').title() for col in table.columns
}), summary_tables)
summary_full = pd.concat(summary_tables).reset_index(drop=True)

# %%
# get rank table
rank_mapping_table = pd.read_csv('../data/final_data/rank-mapping.csv')[['Branch', 'Rank', 'Standardized Pay Grade']]
rank_mapping_table = rank_mapping_table.set_index('Branch')

# %%
###### normalize rank
ranks = (summary_full
 .groupby('Division')['Rank']
 .apply(lambda x: x.value_counts())
 .reset_index()
 .iloc[:, :2]
 .rename(columns={'level_1': 'Rank'})
)

def normalize_rank(row):
    if pd.notnull(row['Rank']):
        branch = rank_mapping_table.loc[row['Division']]
        grade = branch[branch['Rank'] ==  row['Rank']]['Standardized Pay Grade'].unique()
        if len(grade) == 1:
            return grade[0]
    return np.nan

summary_full['Pay Grade'] = summary_full.apply(normalize_rank, axis=1)

# %%
########## normalize date
summary_full['Date'] = summary_full.apply(lambda x: x['Date'] if pd.notnull(x['Date']) else x['Document'], axis=1)

def get_year(date_val):
    if isinstance(date_val, basestring):
        full = re.search('\d{4}', date_val)
        if full:
            return full.group()
        small = re.search('\d{2}', date_val)
        if small:
            return '20' + small.group()
    return np.nan

summary_full['Year'] = summary_full['Date'].apply(get_year)

# %%
## get court martials that have to do with sexual assault
summary_sex_assault_full = summary_full[(summary_full['Offense'].apply(lambda x: 
    (('sex' in x)
     or ('rape' in x)
     or ('raping' in x)
     or ('assault' in x)
     or ('120' in x)
#      or ('134' in x)
     or ('indecent visual recording' in x)
     or ('lawful general order' in x)
#      or ('128' in x)
 ) if pd.notnull(x) else False))].copy()

# %%
def clean_conclusion(row):
    if row['Conclusion'] == 'not guilty':
        if (row.fillna('null')['Sentence'] != 'null'):
            return 'guilty'
    return row['Conclusion']
 
summary_sex_assault_full['Conclusion'] = (summary_sex_assault_full
                      .apply(clean_conclusion, axis=1))

# %% [markdown]
# # Join Outline

# %%
summary_full.head(1).T
# Out:
#                                                                      0
# Allegation                                                         NaN
# City                                                         Yokota AB
# Conclusion                                                      guilty
# Country                                                          Japan
# Court                                                              NaN
# Date                                                            Aug-16
# Division                                                      AIRFORCE
# Document             ../data/airforce/SentencesAIRFORCE/CM_Summ_Aug...
# Gender                                                             NaN
# Name                                                 Stephen N. Mullen
# Offense               by military  judge alone of fraud against the...
# Offense Description                                                NaN
# Orig-Par             At Yokota AB, Japan, Technical Sergeant Stephe...
# Paragraph              At Yokota AB,  Japan,  Technical Sergeant St...
# Rank                                                Technical Sergeant
# Sentence              to reduction to Senior Airman  (E-4),  hard l...
# State                                                              NaN
# Pay Grade                                                          E-6
# Year                                                              2016

# %%
sapro_full.head(1).T
# Out:
#                                                                                                     0
# Administrative Discharge Type                                                                 General
# Adverse Administrative Action Type                                                                NaN
# Alcohol Use                                                                                       NaN
# Case Disposition                                     Sexual Assault Offense: Administrative Discharge
# Case Synopsis                                                                                     NaN
# Case Synopsis Note                                                                                NaN
# Confinement (Court Only)                                                                          NaN
# Correctional Custody (NJP Only)                                                                   NaN
# Court Case or Article 15 Outcome                                            Art 15 Punishment Imposed
# Court- Martial Discharge                                                                          NaN
# Extra Duty                                                                                        YES
# Fines and Forfeiture s                                                                            YES
# Hard Labor                                                                                        NaN
# Location                                                                                        CONUS
# Most Serious Offense Charged                          Wrongful Sexual Contact (FY08 to FY12) Art. 120
# Most Serious Offense Convicted                                        Abusive Sexual Contact Art. 120
# Most Serious Other Offense Charged                                                                NaN
# Most Serious Sexual Assault Allegation Subject ...                                                NaN
# Most Serious Sexual Assault Offense Charged                                                       NaN
# Must Register as Sex Offender                                                                     NaN
# Narrative of the Crime                              Multiple Victims alleged that Subject groped t...
# No.                                                                                                 1
# Offense Alleged/ Investigated                                                  Abusive Sexual Contact
# Quarter Disposition Completed                                                                   Third
# Reason Charges Dismissed at Art 32 Hearing, if ...                                                NaN
# Reason Charges Dismissed at Art 32 Hearing, if ...                                                NaN
# Reduction in Rank                                                                                 NaN
# Restriction                                                                                       YES
# Subject Gender                                                                                   Male
# Subject Pay Grade                                                                                 E-1
# Subject Referral Type                                                                             NaN
# Subject Service                                                                                  Army
# Subject: Moral Waiver Accession                                                                   NaN
# Subject: Moral Waiver Accession?                                                                  NaN
# Subject: Moral Waiver Acession?                                                                   NaN
# Subject: Prior Investigation for Sex Assault?                                                     NaN
# Victim Affiliation                                                                                NaN
# Victim Gender                                                        Multiple Victims - Male & Female
# Victim Pay Grade                                                                     Multiple Victims
# Victim Service                                                                                    NaN
# Year                                                                                             2013

# %% [markdown]
# ## Approach:
#
# 1. Filter on exact matches:
#     * Service
#     * Year
#     * Rank
#     * Country
#     * Gender
#     * Case outcome
# 2. Calculate similarity scores for inexact matches:
#     * Offense
#     * Punishment
#     * Notes

# %%
## exact matches
exact_matches = pd.DataFrame([
    {"type": "Service", "SAPRO": "Subject Service", "SUMMARIES": "Division"},
    {"type": "Year", "SAPRO": "Year", "SUMMARIES": "Year"},
    {"type": "Rank", "SAPRO": "Subject Pay Grade", "SUMMARIES": "Pay Grade"},
#     {"type": "Country", "SAPRO": "Location", "SUMMARIES": "Country"},
    {"type": "Gender", "SAPRO": "Subject Gender", "SUMMARIES": "Gender"},
    {"type": "Case_outcome", "SAPRO": "Outcome", "SUMMARIES": "Conclusion"}
]).set_index("type")

## fuzzy matches
fuzzy_matches = pd.DataFrame([
    {"type": "Notes", "SAPRO": ["Narrative of the Crime"], "SUMMARIES": "Paragraph"},
    {"type":"Punishment",
     "SAPRO": [
        "Confinement (Court Only)", 
        "Fines and Forfeiture s",
        "Reduction in Rank",
        "Court- Martial Discharge",
        "Restriction",
        "Hard Labor",
        "Extra Duty",
        "Correctional Custody (NJP Only)",
        "Adverse Administrative Action Type",
        "Administrative Discharge Type",
        "Must Register as Sex Offender"
    ],
        "SUMMARIES":"Sentence"
    },
    {"type":"Offense","SAPRO":["Most Serious Offense Charged"], "SUMMARIES":"Offense"}
]).set_index("type")

# %%
exact_matches
# Out:
#                           SAPRO   SUMMARIES
# type
# Service         Subject Service    Division
# Year                       Year        Year
# Rank          Subject Pay Grade   Pay Grade
# Gender           Subject Gender      Gender
# Case_outcome            Outcome  Conclusion

# %%
fuzzy_matches
# Out:
#                                                         SAPRO  SUMMARIES
# type
# Notes                                [Narrative of the Crime]  Paragraph
# Punishment  [Confinement (Court Only), Fines and Forfeitur...   Sentence
# Offense                        [Most Serious Offense Charged]    Offense

# %% [markdown]
# ### Normalize Columns

# %%
def clean_sapro_service(service_elem):
    if pd.notnull(service_elem):
        return (service_elem
         .replace('(', '').replace(')', '')
         .replace(' Corps', 's')
         .replace('Air Force', 'AirForce')
         .strip()
         .upper()
    ) 
def clean_summaries_countries(country_row):
    if pd.notnull(country_row):
        country_row = (country_row
         .replace(' a', '')
         .replace('(',''). replace(')', '')
         .replace('U.S.A.', 'USA')
         .replace('MCRD San Diego', 'USA')
         .replace('Calfornia', 'USA')
         .replace('D.C.', 'USA')
      )  
        if country_row in states:
            country_row = 'USA'
        return country_row.upper()

def clean_sapro_country(country_row):
    if pd.notnull(country_row):
        country_row = (country_row.upper()
         .replace('OCONUS', 'USA')
         .replace('CONUS', 'USA')
         .replace('UNITED STATES', 'USA')
         .replace('AFGHANIST AN', 'AFGHANISTAN')
         .replace('AFGHANISTA N', 'AFGHANISTAN')
         .replace('UNKNOW N', 'UNKNOWN')
        )
        if country_row == 'AFGHANISTA':
            country_row = 'AFGHANISTAN'
        if country_row in states:
            country_row = 'USA'
        if country_row == 'US':
            country_row = 'USA'
        if country_row == 'UK':
            country_row = 'United Kingdom'
        if country_row == 'CA,MD':
            country_row = 'USA'
        return country_row.upper()

def sapro_get_court_martial_outcome(row):
    if pd.notnull(row):
        row = row.lower()
        if row !='null':
            if ('dismissed' in row) or ('acquit' in row):
                if ('subsequent' in row) or ('prior' in row):
                    outcome = 'no court-martial'
                else:
                    outcome = 'not guilty'
            elif ('in lieu' in row) or ('article 15' in row) or ('art 15' in row):
                outcome = 'no court-martial'
            else:
                outcome = 'guilty'
            return outcome
    return 'no court-martial'

sapro_full['Subject Service'] = sapro_full['Subject Service'].apply(clean_sapro_service)
summary_sex_assault_full['Country'] = (summary_sex_assault_full['Country']
                                       .apply(
    clean_summaries_countries
))
sapro_full['Location'] = sapro_full['Location'].apply(clean_sapro_country)
sapro_full['Location'] = sapro_full['Location'].apply(clean_sapro_country)
sapro_full['Outcome'] = sapro_full['Court Case or Article 15 Outcome'].apply(
    sapro_get_court_martial_outcome
)
sapro_full['Subject Gender'] = sapro_full['Subject Gender'].apply(
    lambda x: x.lower() if pd.notnull(x) else x
)


summary_sex_assault_full = (summary_sex_assault_full
.applymap(lambda x: unicode(x, encoding='utf-8') if pd.notnull(x) else x)
)

def clean_subject_service(row):
    if pd.isnull(row['Subject Service']):
        if pd.notnull(row['Case Disposition']):
            if row['Case Disposition'] in [
                'Civilian or Foreign Prosecution of Person Not Subject to UCMJ',
                'Unknown Subject',
                'Civilian or Foreign Prosecution of Person Not Subject to',
                'Offender is Unknown',
                'Subject is a Civilian or Foreign National',
                'Unknown']:
                return 'UNKNOWN'
    else:
        return row['Subject Service']

sapro_full['Subject Service'] = sapro_full.apply(clean_subject_service, axis=1)
sapro_full['Subject Pay Grade'] = (sapro_full
   .apply(lambda x: 'UNKNOWN' if  x['Subject Service'] == 'UNKNOWN' else x['Subject Pay Grade']
, axis=1))

import gender_guesser.detector as gender
d = gender.Detector()

def summary_get_gender(row):    
    male_names = ['Alexzander','Frankey','Marckus','Frankey','Jeffary','Juventino',
                  'Jerard','Trentlee','Jarrid','Nehral','Keidrick','Leather','Alexeiv',
                  'Kirkland','Darris',u'Tyrus',u'Cooney', 'Edmourd',
                  'Terance','Vincell','Deandrea','Casey']
    
    gender = row['Gender']
    if pd.isnull(gender):
        if isinstance(row['Name'], basestring) and (row['Name'] != 'null'):
            for name in row['Name'].split(' '):
                if name in male_names:
                    gender = 'male'
                    break
                d_gender = d.get_gender(name)
                d_gender = d_gender.replace('mostly_', '')
                if d_gender in ['male', 'female']:
                    gender = d_gender
                    break
    
    return gender

summary_sex_assault_full['Gender'] = summary_sex_assault_full.apply(summary_get_gender, axis=1)

# %%
sapro_full.isnull().apply(lambda x: x.value_counts())[list(exact_matches['SAPRO'])]
# Out:
#        Subject Service    Year  Subject Pay Grade  Subject Gender  Outcome
# False             8234  8363.0               7938            8206   8363.0
# True               129     NaN                425             157      NaN

# %%
summary_sex_assault_full.isnull().apply(lambda x: x.value_counts())[list(exact_matches['SUMMARIES'])]
# Out:
#        Division  Year  Pay Grade  Gender  Conclusion
# False    2580.0  2575       2540    1627        2578
# True        NaN     5         40     953           2

# %%
## many of the null pay-grades come from SAPRO_charts_airforce_13.pdf, which 
## just doesn't have a pay-grade column

# %%
sapro_full = sapro_full.fillna('null')
summary_sex_assault_full = summary_sex_assault_full.fillna('null')

# %%
subset_SAPRO = sapro_full.copy()
subset_SUMMARIES = summary_sex_assault_full.copy()
values = defaultdict(dict)
for match_type, matcher in exact_matches.iterrows():
    sapro_col = matcher['SAPRO']
    values[match_type]['sapro'] = {'col': sapro_col, 'vals': sapro_full[sapro_col].unique()}
    values[match_type]['sapro'] = sapro_full[sapro_col].unique().tolist()
    
    summ_col = matcher['SUMMARIES']
    values[match_type]['summaries'] = {'col': summ_col, 'vals': summary_sex_assault_full[summ_col].unique() }
    values[match_type]['summaries'] = summary_sex_assault_full[summ_col].unique().tolist()

# %%
all_vals = [
    list(set(field_values['sapro']) & set(field_values['summaries']) - set(['null']))
    for field_values in [values[match_field] for match_field in exact_matches.index]
]

# %%
var_subsets = list(itertools.product(*all_vals))
all_subsets_df = pd.DataFrame(var_subsets, columns=exact_matches.index)

# %%
exact_matches['overlapping-vals'] = all_vals

# %% [markdown]
# ##### this is how many matches we should be finding.... ~ 1500 - 2000

# %%
exact_matches
# Out:
#                           SAPRO   SUMMARIES  \
# type
# Service         Subject Service    Division
# Year                       Year        Year
# Rank          Subject Pay Grade   Pay Grade
# Gender           Subject Gender      Gender
# Case_outcome            Outcome  Conclusion
#
#                                                overlapping-vals
# type
# Service                         [NAVY, MARINES, AIRFORCE, ARMY]
# Year                                   [2015, 2014, 2016, 2013]
# Rank          [E-5, O-5, O-2, W-3, W-2, W-1, O-4, O-1, O-3, ...
# Gender                                           [male, female]
# Case_outcome                               [guilty, not guilty]

# %%
sapro_indexed = sapro_full.reset_index().set_index(list(exact_matches['SAPRO'])).copy()
summ_indexed = summary_sex_assault_full.reset_index().set_index(list(exact_matches['SUMMARIES'])).copy()

# %%
summary_sex_assault_full[list(exact_matches['SUMMARIES'])].pipe(lambda x: x[(x=='null').sum(axis=1)>1])
# Out:
#       Division  Year Pay Grade Gender  Conclusion
# 8     AIRFORCE  2016      null   null  not guilty
# 162   AIRFORCE  2017       E-2   null        null
# 227   AIRFORCE  2017      null   null  not guilty
# 425   AIRFORCE  2016      null   null  not guilty
# 475   AIRFORCE  2016      null   null  not guilty
# 904       ARMY  2017      null   null  not guilty
# 1685      ARMY  2016      null   null  not guilty
# 2309      ARMY  2017      null   null  not guilty
# 2463      ARMY  2016      null   null  not guilty
# 2596      ARMY  2016      null   null  not guilty
# 2705   MARINES  2013      null   null      guilty
# 2795   MARINES  2014      null   null  not guilty
# 2800   MARINES  2014      null   null      guilty
# 2843   MARINES  null      null   null  not guilty
# 2923   MARINES  2014      null   null  not guilty
# 2951   MARINES  2014      null   null      guilty
# 3006   MARINES  2014      null   null  not guilty
# 3122   MARINES  2015      null   null  not guilty
# 3130   MARINES  2015      null   null      guilty
# 3140   MARINES  2015      null   null      guilty
# 3143   MARINES  null      null   null      guilty
# 3148   MARINES  null      null   null  not guilty
# 3151   MARINES  null      null   null      guilty
# 3376   MARINES  2015      null   null  not guilty
# 3383   MARINES  2015      null   null  not guilty
# 3403   MARINES  2015      null   null      guilty
# 3480   MARINES  2016      null   null      guilty
# 3510   MARINES  2016      null   null  not guilty
# 3575   MARINES  2016      null   null  not guilty
# 3584   MARINES  2016      null   null  not guilty
# 3596   MARINES  2016      null   null      guilty
# 3684   MARINES  2016      null   null      guilty
# 3715   MARINES  2016      null   null      guilty
# 3720   MARINES  2016      null   null      guilty
# 3758   MARINES  2017      null   null      guilty
# 3822   MARINES  2017      null   null      guilty
# 3967   MARINES  2017      null   null      guilty

# %%
summ_inst_index
# Out:
# (u'ARMY', '2013', u'E-8', u'female', u'not guilty')

# %%
for i in range(len(summ_inst_index)):
    print tuple(list(summ_inst_index[:i]) + ['null'] + list(summ_inst_index[i+1:]))
# Out:
# ('null', '2013', u'E-8', u'female', u'not guilty')
# (u'ARMY', 'null', u'E-8', u'female', u'not guilty')
# (u'ARMY', '2013', 'null', u'female', u'not guilty')
# (u'ARMY', '2013', u'E-8', 'null', u'not guilty')
# (u'ARMY', '2013', u'E-8', u'female', 'null')

# %%
import time
subsets = {}
now = time.time()
allow_null = True
for idx, combo in enumerate(all_subsets_df.to_dict(orient='records')):
    sapr_subset, summ_subset = pd.DataFrame(), pd.DataFrame()
    
    # get name mapping
    sapr_mapping = []
    summ_mapping = []
    for field in exact_matches.index:
        val = combo[field]
        sapr_name, summ_name = exact_matches.loc[field][['SAPRO','SUMMARIES']]
        sapr_mapping.append((sapr_name, val))
        summ_mapping.append((summ_name, val))
    
    sapr_inst_index = tuple(map(lambda x: x[1], sapr_mapping))
    summ_inst_index = tuple(map(lambda x: x[1], summ_mapping))
    
    # SAPRO indexing
    if sapro_indexed.index.contains(sapr_inst_index): 
        sapr_subset = pd.concat([
            sapr_subset,
            sapro_indexed.loc[sapr_inst_index]]
        )
    if allow_null:
        # allow one column to be 'null
        for i in range(len(sapr_inst_index)):
            other = tuple(list(sapr_inst_index[:i]) + ['null'] + list(sapr_inst_index[i+1:]))
            if sapro_indexed.index.contains(other):
                sapr_subset = pd.concat([
                    sapr_subset,
                    sapro_indexed.loc[other]
                ])
    
    # SUMMARY indexing
    if summ_indexed.index.contains(summ_inst_index):
        summ_subset = pd.concat([
            summ_subset,
            summ_indexed.loc[summ_inst_index]
        ])

    if allow_null:
        # allow one column to be null
        for i in range(len(summ_inst_index)):
            other = tuple(list(summ_inst_index[:i]) + ['null'] + list(summ_inst_index[i+1:]))
            if summ_indexed.index.contains(other):
                summ_subset = pd.concat([
                    summ_subset,
                    summ_indexed.loc[other]
                ])
    
    # report results
    combo_title = '__'.join(map(lambda x: '(' + x[0] + ':' + x[1] + ')', combo.items()))
    subsets[combo_title] = {
        'sapr_subset': sapr_subset,
        'summ_subset': summ_subset
    }
# Out:
# /Users/206309/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:24: PerformanceWarning: indexing past lexsort depth may impact performance.
# /Users/206309/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:40: PerformanceWarning: indexing past lexsort depth may impact performance.
# /Users/206309/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:50: PerformanceWarning: indexing past lexsort depth may impact performance.
# /Users/206309/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:33: PerformanceWarning: indexing past lexsort depth may impact performance.

# %%
subset_df = pd.DataFrame.from_dict(subsets, orient='index')

# reset index
subset_df = pd.concat([subset_df.reset_index(drop=True), (subset_df
     .reset_index()['index']
     .apply(lambda x: pd.Series({
         item.replace('(','').replace(')', '').split(':')[0]:
         item.replace('(','').replace(')', '').split(':')[1]
      for item in x.split('__')})))], axis=1)

subset_df = subset_df.set_index([
    'Service',
    'Case_outcome',
    'Gender',
    'Rank',
    'Year'
])

# %%
subset_counts = subset_df.applymap(len)

# %%
subset_counts.sum()
# Out:
# summ_subset    2593
# sapr_subset    4924
# dtype: int64

# %%
print 'missing from sapro...'
print subset_counts[(subset_counts.summ_subset > 0) & (subset_counts.sapr_subset == 0)].sum()
print 
print 'missing from summaries...'
print subset_counts[(subset_counts.summ_subset == 0) & (subset_counts.sapr_subset > 0)].sum()
# Out:
# missing from sapro...
# summ_subset    651
# sapr_subset      0
# dtype: int64
#
# missing from summaries...
# summ_subset       0
# sapr_subset    2619
# dtype: int64

# %%
(subset_counts
 [(subset_counts.summ_subset > 0) & (subset_counts.sapr_subset == 0)]
 .reset_index('Case_outcome')
  .groupby('Case_outcome').sum()
)
# Out:
#               summ_subset  sapr_subset
# Case_outcome
# guilty                360            0
# not guilty            291            0

# %%
(subset_counts
 [(subset_counts.summ_subset == 0) & (subset_counts.sapr_subset > 0)]
 .reset_index('Case_outcome')
 .groupby('Case_outcome').sum()
)
# Out:
#               summ_subset  sapr_subset
# Case_outcome
# guilty                  0          877
# not guilty              0         1742

# %%
(subset_df
 .pipe(lambda df: df[
     (df['summ_subset'].apply(len) > 0) &
     (df['sapr_subset'].apply(len) == 0)
 ]))
# Out:
#                                                                               summ_subset  \
# Service  Case_outcome Gender Rank Year
# MARINES  guilty       female E-1  2013                                             ind...
#                                   2014                                             ind...
#                                   2015                                             ind...
#                                   2016                                             ind...
#                              E-2  2013                                             ind...
#                                   2014                                             ind...
#                                   2016                                             ind...
# NAVY     guilty       female E-2  2016                                             ind...
# AIRFORCE guilty       female E-3  2013                                             ind...
# ARMY     guilty       female E-3  2015                                             ind...
# MARINES  guilty       female E-3  2014                                             ind...
#                                   2016                                             ind...
# AIRFORCE guilty       female E-4  2013                                             ind...
# MARINES  guilty       female E-4  2013                                             ind...
#                                   2014                                             ind...
#                                   2015                                             ind...
#                                   2016                                             ind...
# NAVY     guilty       female E-4  2014                                             ind...
# ARMY     guilty       female E-5  2016                                             ind...
# MARINES  guilty       female E-5  2013                                             ind...
#                                   2014                                             ind...
#                                   2015                                             ind...
#                                   2016                                             ind...
# AIRFORCE guilty       female E-6  2014                                             ind...
# ARMY     guilty       female E-6  2015                                             ind...
# MARINES  guilty       female E-6  2013                                             ind...
#                                   2014                                             ind...
#                                   2015                                             ind...
#                                   2016                                             ind...
# ARMY     guilty       female E-7  2015                                             ind...
# ...                                                                                   ...
# MARINES  not guilty   female E-6  2016                                             ind...
# NAVY     not guilty   female E-6  2013                                             ind...
#                                   2015                                             ind...
# MARINES  not guilty   female E-7  2015                                             ind...
#                                   2016                                             ind...
# NAVY     not guilty   female E-7  2014                                             ind...
#                                   2015                                             ind...
#                              E-8  2014                                             ind...
#                                   2015                                             ind...
#                                   2016                                             ind...
#                              E-9  2013                                             ind...
# MARINES  not guilty   female O-1  2014                                             ind...
# NAVY     not guilty   female O-1  2015                                             ind...
# ARMY     not guilty   female O-2  2016                                             ind...
# NAVY     not guilty   female O-2  2014                                             ind...
#                                   2015                                             ind...
# ARMY     not guilty   female O-3  2015                                             ind...
#                                   2016                                             ind...
# NAVY     not guilty   female O-3  2014                                             ind...
#                                   2016                                             ind...
# ARMY     not guilty   female O-4  2016                                             ind...
# NAVY     not guilty   female O-4  2014                                             ind...
#                              O-6  2015                                             ind...
# MARINES  not guilty   male   E-6  2014                                             ind...
# NAVY     not guilty   male   E-8  2014                                             ind...
#                                   2016                                             ind...
#                              E-9  2013                                             ind...
# MARINES  not guilty   male   O-1  2014                                             ind...
# NAVY     not guilty   male   O-2  2014                                             ind...
# ARMY     not guilty   male   O-3  2015                                             ind...
#
#                                                                   sapr_subset
# Service  Case_outcome Gender Rank Year
# MARINES  guilty       female E-1  2013  Empty DataFrame
# Columns: []
# Index: []
#                                   2014  Empty DataFrame
# Columns: []
# Index: []
#                                   2015  Empty DataFrame
# Columns: []
# Index: []
#                                   2016  Empty DataFrame
# Columns: []
# Index: []
#                              E-2  2013  Empty DataFrame
# Columns: []
# Index: []
#                                   2014  Empty DataFrame
# Columns: []
# Index: []
#                                   2016  Empty DataFrame
# Columns: []
# Index: []
# NAVY     guilty       female E-2  2016  Empty DataFrame
# Columns: []
# Index: []
# AIRFORCE guilty       female E-3  2013  Empty DataFrame
# Columns: []
# Index: []
# ARMY     guilty       female E-3  2015  Empty DataFrame
# Columns: []
# Index: []
# MARINES  guilty       female E-3  2014  Empty DataFrame
# Columns: []
# Index: []
#                                   2016  Empty DataFrame
# Columns: []
# Index: []
# AIRFORCE guilty       female E-4  2013  Empty DataFrame
# Columns: []
# Index: []
# MARINES  guilty       female E-4  2013  Empty DataFrame
# Columns: []
# Index: []
#                                   2014  Empty DataFrame
# Columns: []
# Index: []
#                                   2015  Empty DataFrame
# Columns: []
# Index: []
#                                   2016  Empty DataFrame
# Columns: []
# Index: []
# NAVY     guilty       female E-4  2014  Empty DataFrame
# Columns: []
# Index: []
# ARMY     guilty       female E-5  2016  Empty DataFrame
# Columns: []
# Index: []
# MARINES  guilty       female E-5  2013  Empty DataFrame
# Columns: []
# Index: []
#                                   2014  Empty DataFrame
# Columns: []
# Index: []
#                                   2015  Empty DataFrame
# Columns: []
# Index: []
#                                   2016  Empty DataFrame
# Columns: []
# Index: []
# AIRFORCE guilty       female E-6  2014  Empty DataFrame
# Columns: []
# Index: []
# ARMY     guilty       female E-6  2015  Empty DataFrame
# Columns: []
# Index: []
# MARINES  guilty       female E-6  2013  Empty DataFrame
# Columns: []
# Index: []
#                                   2014  Empty DataFrame
# Columns: []
# Index: []
#                                   2015  Empty DataFrame
# Columns: []
# Index: []
#                                   2016  Empty DataFrame
# Columns: []
# Index: []
# ARMY     guilty       female E-7  2015  Empty DataFrame
# Columns: []
# Index: []
# ...                                                                       ...
# MARINES  not guilty   female E-6  2016  Empty DataFrame
# Columns: []
# Index: []
# NAVY     not guilty   female E-6  2013  Empty DataFrame
# Columns: []
# Index: []
#                                   2015  Empty DataFrame
# Columns: []
# Index: []
# MARINES  not guilty   female E-7  2015  Empty DataFrame
# Columns: []
# Index: []
#                                   2016  Empty DataFrame
# Columns: []
# Index: []
# NAVY     not guilty   female E-7  2014  Empty DataFrame
# Columns: []
# Index: []
#                                   2015  Empty DataFrame
# Columns: []
# Index: []
#                              E-8  2014  Empty DataFrame
# Columns: []
# Index: []
#                                   2015  Empty DataFrame
# Columns: []
# Index: []
#                                   2016  Empty DataFrame
# Columns: []
# Index: []
#                              E-9  2013  Empty DataFrame
# Columns: []
# Index: []
# MARINES  not guilty   female O-1  2014  Empty DataFrame
# Columns: []
# Index: []
# NAVY     not guilty   female O-1  2015  Empty DataFrame
# Columns: []
# Index: []
# ARMY     not guilty   female O-2  2016  Empty DataFrame
# Columns: []
# Index: []
# NAVY     not guilty   female O-2  2014  Empty DataFrame
# Columns: []
# Index: []
#                                   2015  Empty DataFrame
# Columns: []
# Index: []
# ARMY     not guilty   female O-3  2015  Empty DataFrame
# Columns: []
# Index: []
#                                   2016  Empty DataFrame
# Columns: []
# Index: []
# NAVY     not guilty   female O-3  2014  Empty DataFrame
# Columns: []
# Index: []
#                                   2016  Empty DataFrame
# Columns: []
# Index: []
# ARMY     not guilty   female O-4  2016  Empty DataFrame
# Columns: []
# Index: []
# NAVY     not guilty   female O-4  2014  Empty DataFrame
# Columns: []
# Index: []
#                              O-6  2015  Empty DataFrame
# Columns: []
# Index: []
# MARINES  not guilty   male   E-6  2014  Empty DataFrame
# Columns: []
# Index: []
# NAVY     not guilty   male   E-8  2014  Empty DataFrame
# Columns: []
# Index: []
#                                   2016  Empty DataFrame
# Columns: []
# Index: []
#                              E-9  2013  Empty DataFrame
# Columns: []
# Index: []
# MARINES  not guilty   male   O-1  2014  Empty DataFrame
# Columns: []
# Index: []
# NAVY     not guilty   male   O-2  2014  Empty DataFrame
# Columns: []
# Index: []
# ARMY     not guilty   male   O-3  2015  Empty DataFrame
# Columns: []
# Index: []
#
# [143 rows x 2 columns]

# %% [markdown]
# # Matches

# %%
subset_match_df = subset_df.pipe(lambda df: df[(df.applymap(len) > 0).all(axis=1)])

# %%
subset_match_df.pipe(lambda df: df[(df.applymap(len) == 1).all(axis=1)])
# Out:
#                                                                              summ_subset  \
# Service Case_outcome Gender Rank Year
# ARMY    guilty       male   E-9  2015                                             ind...
#                                  2016                                             ind...
# MARINES guilty       male   E-9  2015                                             ind...
# NAVY    guilty       male   E-9  2013                                             ind...
# ARMY    guilty       male   O-5  2015                                             ind...
#                             W-2  2015                                             ind...
#                             W-3  2015                                             ind...
#                                  2016                                             ind...
# NAVY    not guilty   female E-3  2013                                             ind...
# MARINES not guilty   female E-5  2013                                             ind...
# NAVY    not guilty   female E-6  2014                                             ind...
# MARINES not guilty   male   E-1  2014                                             ind...
#                             E-2  2016                                             ind...
# NAVY    not guilty   male   E-2  2016                                             ind...
# MARINES not guilty   male   E-6  2016                                             ind...
# NAVY    not guilty   male   E-8  2015                                             ind...
#                             O-2  2015                                             ind...
#                             O-3  2016                                             ind...
#                             O-6  2015                                             ind...
#
#                                                                              sapr_subset
# Service Case_outcome Gender Rank Year
# ARMY    guilty       male   E-9  2015                                                ...
#                                  2016                                                ...
# MARINES guilty       male   E-9  2015                                                ...
# NAVY    guilty       male   E-9  2013                                                ...
# ARMY    guilty       male   O-5  2015                                                ...
#                             W-2  2015                                                ...
#                             W-3  2015                                                ...
#                                  2016                                                ...
# NAVY    not guilty   female E-3  2013                                                ...
# MARINES not guilty   female E-5  2013                                                ...
# NAVY    not guilty   female E-6  2014                                                ...
# MARINES not guilty   male   E-1  2014                                                ...
#                             E-2  2016                                                ...
# NAVY    not guilty   male   E-2  2016                                                ...
# MARINES not guilty   male   E-6  2016                                                ...
# NAVY    not guilty   male   E-8  2015                                                ...
#                             O-2  2015                                                ...
#                             O-3  2016                                                ...
#                             O-6  2015                                                ...

# %%
subset_match_df.pipe(lambda df: df[(df.applymap(len) == 2).all(axis=1)])
# Out:
#                                                                              summ_subset  \
# Service Case_outcome Gender Rank Year
# MARINES guilty       male   E-8  2016                                             ind...
# NAVY    guilty       male   O-2  2014                                             ind...
# MARINES not guilty   male   E-1  2016                                             ind...
#
#                                                                              sapr_subset
# Service Case_outcome Gender Rank Year
# MARINES guilty       male   E-8  2016                                                ...
# NAVY    guilty       male   O-2  2014                                                ...
# MARINES not guilty   male   E-1  2016                                                ...

# %%
subset_match_df.pipe(lambda df: df[(df.applymap(len) == 3).all(axis=1)])
# Out:
#                                                                              summ_subset  \
# Service Case_outcome Gender Rank Year
# ARMY    not guilty   male   E-1  2015                                             ind...
# NAVY    not guilty   male   E-6  2015                                             ind...
#
#                                                                              sapr_subset
# Service Case_outcome Gender Rank Year
# ARMY    not guilty   male   E-1  2015                                                ...
# NAVY    not guilty   male   E-6  2015                                                ...

# %%
fuzzy_matches
# Out:
#                                                         SAPRO  SUMMARIES
# type
# Notes                                [Narrative of the Crime]  Paragraph
# Punishment  [Confinement (Court Only), Fines and Forfeitur...   Sentence
# Offense                        [Most Serious Offense Charged]    Offense

# %%
sapr_subset[fuzzy_matches.loc['Punishment', 'SAPRO']]
# Out:
#                                                                  Confinement (Court Only)  \
# Subject Service Year Subject Pay Grade Subject Gender Outcome
# NAVY            2015 O-6               male           not guilty                     null
#
#                                                                  Fines and Forfeiture s  \
# Subject Service Year Subject Pay Grade Subject Gender Outcome
# NAVY            2015 O-6               male           not guilty                   null
#
#                                                                  Reduction in Rank  \
# Subject Service Year Subject Pay Grade Subject Gender Outcome
# NAVY            2015 O-6               male           not guilty              null
#
#                                                                  Court- Martial Discharge  \
# Subject Service Year Subject Pay Grade Subject Gender Outcome
# NAVY            2015 O-6               male           not guilty                     null
#
#                                                                  Restriction  \
# Subject Service Year Subject Pay Grade Subject Gender Outcome
# NAVY            2015 O-6               male           not guilty        null
#
#                                                                  Hard Labor  \
# Subject Service Year Subject Pay Grade Subject Gender Outcome
# NAVY            2015 O-6               male           not guilty       null
#
#                                                                  Extra Duty  \
# Subject Service Year Subject Pay Grade Subject Gender Outcome
# NAVY            2015 O-6               male           not guilty       null
#
#                                                                  Correctional Custody (NJP Only)  \
# Subject Service Year Subject Pay Grade Subject Gender Outcome
# NAVY            2015 O-6               male           not guilty                            null
#
#                                                                  Adverse Administrative Action Type  \
# Subject Service Year Subject Pay Grade Subject Gender Outcome
# NAVY            2015 O-6               male           not guilty                               null
#
#                                                                  Administrative Discharge Type  \
# Subject Service Year Subject Pay Grade Subject Gender Outcome
# NAVY            2015 O-6               male           not guilty                          null
#
#                                                                  Must Register as Sex Offender
# Subject Service Year Subject Pay Grade Subject Gender Outcome
# NAVY            2015 O-6               male           not guilty                          null

# %%
scores = []
for idx, item in subset_match_df.iterrows():
    summ_subset, sapr_subset = item
    for summ in summ_subset['Paragraph']:
        for sapr in sapr_subset['Narrative of the Crime']:
            scores.append({
                'summ': summ,
                'sapr': sapr,
                'ratio': fuzz.token_set_ratio(summ, sapr)
            })

# %%
sapro_full[fuzzy_matches.loc['Punishment', 'SAPRO']]
# Out:
#      Confinement (Court Only) Fines and Forfeiture s Reduction in Rank  \
# 0                        null                    YES              null
# 1                        null                   null              null
# 2                        null                   null              null
# 3                        null                   null              null
# 4                        null                   null              null
# 5                        null                   null              null
# 6                        null                   null              null
# 7                        null                   null              null
# 8                        null                   null              null
# 9                        null                    YES               YES
# 10                       null                   null              null
# 11                       null                    YES              null
# 12                       null                   null              null
# 13                       null                   null              null
# 14                       null                   null              null
# 15                       null                    YES              null
# 16                       null                   null              null
# 17                       null                   null              null
# 18                       null                   null              null
# 19                       null                   null              null
# 20                       null                   null              null
# 21                       null                    YES              null
# 22                       null                   null              null
# 23                       null                   null              null
# 24                       null                   null              null
# 25                       null                   null              null
# 26                       null                    YES               YES
# 27                       null                   null              null
# 28                       null                   null              null
# 29                       null                   null              null
# ...                       ...                    ...               ...
# 8333                     null                   null              null
# 8334                     null                   null              null
# 8335                     null                   null              null
# 8336                     null                   null              null
# 8337                     null                   null              null
# 8338                     null                   null              null
# 8339                     null                   null              null
# 8340                     null                   null              null
# 8341                     null                   null              null
# 8342                     null                   null              null
# 8343                     null                   null              null
# 8344                     null                   null              null
# 8345                     null                   null              null
# 8346                     null                   null              null
# 8347                     null                   null              null
# 8348                     null                   null              null
# 8349                     null                   null              null
# 8350                     null                   null              null
# 8351                     null                   null              null
# 8352                     null                   null              null
# 8353                     null                   null              null
# 8354                     null                   null              null
# 8355                     null                   null              null
# 8356                     null                   null              null
# 8357                     null                   null              null
# 8358                     null                   null              null
# 8359                     null                   null              null
# 8360                     null                   null              null
# 8361                     null                   null              null
# 8362                     null                   null              null
#
#      Court- Martial Discharge Restriction Hard Labor Extra Duty  \
# 0                        null         YES       null        YES
# 1                        null        null       null       null
# 2                        null        null       null       null
# 3                        null        null       null       null
# 4                        null        null       null       null
# 5                        null        null       null       null
# 6                        null        null       null       null
# 7                        null        null       null       null
# 8                        null        null       null       null
# 9                        null         YES       null        YES
# 10                       null        null       null       null
# 11                       null         YES       null        YES
# 12                       null        null       null       null
# 13                       null        null       null       null
# 14                       null        null       null       null
# 15                       null         YES       null        YES
# 16                       null        null       null       null
# 17                       null        null       null       null
# 18                       null        null       null       null
# 19                       null        null       null       null
# 20                       null        null       null       null
# 21                       null         YES       null        YES
# 22                       null        null       null       null
# 23                       null        null       null       null
# 24                       null        null       null       null
# 25                       null        null       null       null
# 26                       null        null       null        YES
# 27                       null        null       null       null
# 28                       null        null       null       null
# 29                       null        null       null       null
# ...                       ...         ...        ...        ...
# 8333                     null        null       null       null
# 8334                     null        null       null       null
# 8335                     null        null       null       null
# 8336                     null        null       null       null
# 8337                     null        null       null       null
# 8338                     null        null       null       null
# 8339                     null        null       null       null
# 8340                     null        null       null       null
# 8341                     null        null       null       null
# 8342                     null        null       null       null
# 8343                     null        null       null       null
# 8344                     null        null       null       null
# 8345                     null        null       null       null
# 8346                     null        null       null       null
# 8347                     null        null       null       null
# 8348                     null        null       null       null
# 8349                     null        null       null       null
# 8350                     null        null       null       null
# 8351                     null        null       null       null
# 8352                     null        null       null       null
# 8353                     null        null       null       null
# 8354                     null        null       null       null
# 8355                     null        null       null       null
# 8356                     null        null       null       null
# 8357                     null        null       null       null
# 8358                     null        null       null       null
# 8359                     null        null       null       null
# 8360                     null        null       null       null
# 8361                     null        null       null       null
# 8362                     null        null       null       null
#
#      Correctional Custody (NJP Only) Adverse Administrative Action Type  \
# 0                               null                               null
# 1                               null                               null
# 2                               null                               null
# 3                               null                               null
# 4                               null                               null
# 5                               null                               null
# 6                               null                               null
# 7                               null                               null
# 8                               null                               null
# 9                               null                               null
# 10                              null                               null
# 11                              null                               null
# 12                              null                               null
# 13                              null                               null
# 14                              null                               null
# 15                              null                               null
# 16                              null                               null
# 17                              null                               null
# 18                              null                               null
# 19                              null                               null
# 20                              null                                LOR
# 21                              null                               null
# 22                              null                               null
# 23                              null                               null
# 24                              null                               null
# 25                              null                               null
# 26                              null                               null
# 27                              null                               null
# 28                              null                               null
# 29                              null                                LOR
# ...                              ...                                ...
# 8333                            null                               null
# 8334                            null                               null
# 8335                            null                               null
# 8336                            null                               null
# 8337                            null                               null
# 8338                            null                               null
# 8339                            null                               null
# 8340                            null                               null
# 8341                            null                               null
# 8342                            null                               null
# 8343                            null                               null
# 8344                            null                               null
# 8345                            null                               null
# 8346                            null                               null
# 8347                            null                               null
# 8348                            null                               null
# 8349                            null                               null
# 8350                            null                               null
# 8351                            null                               null
# 8352                            null                               null
# 8353                            null                               null
# 8354                            null                               null
# 8355                            null                               null
# 8356                            null                               null
# 8357                            null                               null
# 8358                            null                               null
# 8359                            null                               null
# 8360                            null                               null
# 8361                            null                               null
# 8362                            null                               null
#
#                       Administrative Discharge Type  \
# 0                                           General
# 1                                           General
# 2                                           General
# 3                                           Pending
# 4                                   Uncharacterized
# 5                                   Uncharacterized
# 6                                             UOTHC
# 7                                           General
# 8                                           General
# 9                                           General
# 10                                            UOTHC
# 11                                          General
# 12                                          General
# 13                                  Uncharacterized
# 14                                            UOTHC
# 15                                          General
# 16                                        Honorable
# 17                                          General
# 18                                          General
# 19                                            UOTHC
# 20                                          General
# 21                                          General
# 22                                  Uncharacterized
# 23                                          General
# 24                                          General
# 25                                          General
# 26                                          General
# 27                                  Uncharacterized
# 28                                          General
# 29                                          Pending
# ...                                             ...
# 8333                                           null
# 8334                                           null
# 8335                                           None
# 8336                                           null
# 8337                                           null
# 8338                                           null
# 8339                                        General
# 8340                                           null
# 8341                                           None
# 8342                                        General
# 8343                                           null
# 8344                                           None
# 8345                                        General
# 8346  Under Other than Honorable Conditions (UOTHC)
# 8347                                           None
# 8348                                           null
# 8349  Under Other than Honorable Conditions (UOTHC)
# 8350                                           null
# 8351                                           None
# 8352                                           null
# 8353                                           null
# 8354                                           null
# 8355                                           None
# 8356                                           null
# 8357                                           null
# 8358                                           null
# 8359                                           None
# 8360  Under Other than Honorable Conditions (UOTHC)
# 8361                                           null
# 8362                                           null
#
#      Must Register as Sex Offender
# 0                             null
# 1                             null
# 2                             null
# 3                             null
# 4                             null
# 5                             null
# 6                             null
# 7                             null
# 8                             null
# 9                             null
# 10                            null
# 11                            null
# 12                            null
# 13                            null
# 14                            null
# 15                            null
# 16                            null
# 17                            null
# 18                            null
# 19                            null
# 20                            null
# 21                            null
# 22                            null
# 23                            null
# 24                            null
# 25                            null
# 26                            null
# 27                            null
# 28                            null
# 29                            null
# ...                            ...
# 8333                          null
# 8334                          null
# 8335                          null
# 8336                          null
# 8337                          null
# 8338                          null
# 8339                          null
# 8340                          null
# 8341                          null
# 8342                          null
# 8343                          null
# 8344                           Yes
# 8345                          null
# 8346                          null
# 8347                           Yes
# 8348                           Yes
# 8349                          null
# 8350                          null
# 8351                          null
# 8352                          null
# 8353                          null
# 8354                          null
# 8355                          null
# 8356                          null
# 8357                          null
# 8358                          null
# 8359                          null
# 8360                          null
# 8361                          null
# 8362                          null
#
# [8363 rows x 11 columns]

# %%
pd.DataFrame(scores)
# Out:
#        ratio                                               sapr  \
# 0          3                                               null
# 1          3                                               null
# 2          2                                               null
# 3          2                                               null
# 4          2                                               null
# 5          2                                               null
# 6          2                                               null
# 7         49  On-base offense where Marine Subject pinned Ma...
# 8         50  On-base offense where Marine Subject pinned Ma...
# 9         54  On-base offense where Marine Subject pinned Ma...
# 10        52  On-base offense where Marine Subject pinned Ma...
# 11        52  On-base offense where Marine Subject pinned Ma...
# 12        53  On-base offense where Marine Subject pinned Ma...
# 13        49  On-base offense where Marine Subject pinned Ma...
# 14         4                                               null
# 15         4                                               null
# 16         2                                               null
# 17         2                                               null
# 18         2                                               null
# 19         2                                               null
# 20         3                                               null
# 21         3                                               null
# 22         2                                               null
# 23         2                                               null
# 24         2                                               null
# 25         2                                               null
# 26         3                                               null
# 27         3                                               null
# 28         2                                               null
# 29         2                                               null
# ...      ...                                                ...
# 31265      5                                               null
# 31266      4                                               null
# 31267      4                                               null
# 31268      5                                               null
# 31269      5                                               null
# 31270      5                                               null
# 31271      5                                               null
# 31272      5                                               null
# 31273      5                                               null
# 31274      4                                               null
# 31275      4                                               null
# 31276      4                                               null
# 31277      2                                               null
# 31278      2                                               null
# 31279      5                                               null
# 31280      3                                               null
# 31281      3                                               null
# 31282      4                                               null
# 31283      3                                               null
# 31284      4                                               null
# 31285      4                                               null
# 31286      4                                               null
# 31287      5                                               null
# 31288      3                                               null
# 31289      3                                               null
# 31290      4                                               null
# 31291      3                                               null
# 31292      5                                               null
# 31293      3                                               null
# 31294      5                                               null
#
#                                                     summ
# 0      At a Special Court-Martial at Camp Pendleton, ...
# 1      At a General Court-Martial at Miramar,  Califo...
# 2      At a Special Court-Martial at Camp Pendleton, ...
# 3      At a Special Court-Martial at Camp Pendleton, ...
# 4      At a Special Court-Martial in Okinawa,  Japan,...
# 5      At a General Court-Martial at Camp Lejeune,  N...
# 6      At a Special Court-martial at San Diego,  Cali...
# 7      At a General Court-Martial at Camp Foster,  Ok...
# 8      At a Special Court-Martial at Camp Pendleton, ...
# 9      At a Special Court-Martial at Camp Pendleton, ...
# 10     At a Special Court-Martial at Kaneohe Bay,  Ha...
# 11     At a Special Court-Martial at Kaneohe Bay,  Ha...
# 12     At a General Court-Martial at Camp Lejeune,  N...
# 13     At a Special Court-Martial at Camp Pendleton, ...
# 14     At a General Court-Martial at Camp Pendleton, ...
# 15     At a General Court-Martial at Camp Pendleton, ...
# 16     At a General Court-Martial at Okinawa,  Japan,...
# 17     At a General Court-Martial at Okinawa,  Japan,...
# 18     At a General Court-Martial at MCAS Miramar,  C...
# 19     At a General Court-Martial at MCAS Miramar,  C...
# 20     At a Special Court-Martial at 29 Palms,  Calif...
# 21     At a Special Court-Martial at 29 Palms,  Calif...
# 22     At a General Court-Martial at Miramar,  Califo...
# 23     At a General Court-Martial at Miramar,  Califo...
# 24     At a General Court-Martial at Miramar,  Califo...
# 25     At a General Court-Martial at Miramar,  Califo...
# 26     At a Special Court-Martial at 29 Palms,  Calif...
# 27     At a Special Court-Martial at 29 Palms,  Calif...
# 28     At a Special Court-Martial at Okinawa,  Japan,...
# 29     At a Special Court-Martial at Okinawa,  Japan,...
# ...                                                  ...
# 31265  At a Special Court-Martial at 29 Palms,  Calif...
# 31266  At a Special Court-Martial at Camp Pendleton, ...
# 31267  At a Special Court-Martial at Camp Pendleton, ...
# 31268  At a Special Court-Martial at San Diego,  Cali...
# 31269  At a Special Court-Martial at San Diego,  Cali...
# 31270   Special Court-Martial in Rota, Spain, an E-7 ...
# 31271   General Court-Martial in Yokosuka, Japan, an ...
# 31272   Special Court-Martial in Yokosuka, Japan, an ...
# 31273   Special Court-Martial in Yokosuka, Japan, an ...
# 31274   Special Court-Martial in Norfolk, Virginia, a...
# 31275   General Court-Martial in Washington, D.C., an...
# 31276   General Court-Martial in Washington, D.C., an...
# 31277  09 June 2016, at a general court-martial conve...
# 31278  09 June 2016, at a general court-martial conve...
# 31279   General Court-Martial in Mayport Florida, an ...
# 31280  9 October 2014, at a General Court-Martial at ...
# 31281  9 October 2014, at a General Court-Martial at ...
# 31282  15 December 2016, at a general court-martial c...
# 31283  06 January 2016, at a general court-martial co...
# 31284  19 October 2016, at a general court-martial co...
# 31285   General Court-Martial in Norfolk, Virginia, a...
# 31286   General Court-Martial in Norfolk, Virginia, a...
# 31287   General Court-Martial in Norfolk, Virginia, a...
# 31288  22 January 2015, at a general court-martial co...
# 31289  22 January 2015, at a general court-martial co...
# 31290  21 June 2016, at a general court-martial conve...
# 31291  29 September 2016, at a general court-martial ...
# 31292   General Court-Martial in Washington, D.C., an...
# 31293   General Court-Martial in San Diego, Californi...
# 31294   General Court Martial in Bremerton, Washingto...
#
# [31295 rows x 3 columns]

# %%
subset_match_df.iloc[7]['sapr_subset']['Case Synopsis Note'].values
# Out:
# array([u'Courts-Martial discharge: BCD - Bad Conduct Discharge; Confinement: No; Forfeiture of Pay and Allowances: Yes; Fine: No; Restriction: Yes; Restriction Limit: Quarters; Restriction Length (Days): 120; Reduction in rank: No; Hard Labor: No; Notes: Victim reported that subject forcibly kissed her and touched her without her consent while walking away from the bowling alley on base. Both Victim and Subject had conusmed alcohol. NCIS conducted an investigation. The Convening Authority reviewed the investigation and considered the views of the victim. After consultation with the SJA and Trial Counsel, the Convening Authority referred charges to SPCM. In accordance with a pretrial agreement , the Convening Authority withdrew the Art. 120 charges and Subject entered pleas of Guilty for three specifications of Art. 128 and of Art. 91.',
#        u"Courts-Martial discharge: DD - Dishonorable Discharge; Confinement: Yes; Confinement Type: Less Than Life; Confinement (Months): 48; Forfeiture of Pay and Allowances: No; Fine: No; Restriction: No; Reduction in rank: No; Hard Labor: No; Notes: Victim reported that the Subject wrongfully touched her and attempted to rape her. NCIS conducted an investigation. Charges were preferred for sexual related offenses. After reviewing the investigation, consulting with the SJA, Victim Legal Counsel, and considering the views of the victims, the Convening Authority referred the following charges to GCM: Art. 80 - Attempted Rape; Art. 86 - Unauthorized Absence; Art. 120 - Aggravated Sexual Contact Art. 128x2 - Assault Consummated by a Battery - (by grabbing V's head and by covering V's mouth and nose); Art. 134 - Indecent Language; and, Art. 134 - Obstructing Justice. Pursuant of the pre-trial agreement, the Subject pled guilty."],
#       dtype=object)

# %% [markdown]
# ##### column lengths

# %%
(airforce_sapro_2013
 .iloc[0]
 .apply(lambda x: len(x) if isinstance(x, basestring) else 0 )
 .pipe(lambda s: s[s > 15])
)
# Out:
# Case\rDisposition          67
# Alcohol\rUse               24
# Narrative of the Crime    112
# Name: 407, dtype: int64

# %%
(airforce_summaries_2013
 .iloc[0]
 .apply(lambda x: len(x) if isinstance(x, basestring) else 0 )
 .pipe(lambda s: s[s > 15])
)
# Out:
# Allegation    180
# Document       20
# Name           16
# Offense       163
# Sentence       98
# Name: 507, dtype: int64

# %%
sapro_columns = ['Narrative of the Crime']
summary_columns= ['Allegation', 'Offense']

# %%
airforce_sapro_2013[sapro_columns].head()
# Out:
#                                  Narrative of the Crime
# 407   Victim alleged that an Air Force Subject perfo...
# 478   Victim alleged that an Air Force Subject perfo...
# 1085  Off-Base offense involving alcohol. USN Victim...
# 1186  Off-base offense involving alcohol.  Victim an...
# 1762  Victim #1 attended a wedding where she met Sub...

# %%
import fasttext

# %%
model = fasttext.load_model('../data/model_files/wiki-news-300d-1M.vec')

# %% [markdown]
# # Data Analysis
